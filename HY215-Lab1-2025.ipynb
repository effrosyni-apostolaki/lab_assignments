# %% [markdown]
# <div align="center">
#
# # ΠΑΝΕΠΙΣΤΗΜΙΟ ΚΡΗΤΗΣ
# # Τμήμα Επιστήμης Υπολογιστών
#
# ## HY-215: Εφαρμοσμένα Μαθηματικά για Μηχανικούς
# ## Εαρινό Εξάμηνο 2024-2025
# ### Διδάσκων: Γ. Καφεντζής
#
# ## Ανάθεση: 26-2-2025
# ## Παράδοση (ηλεκτρονικά, όπως αναφέρεται στην ιστοσελίδα του μαθήματος):
# ## Κυριακή, 9-3-2025, 23:59:59
# <h1><center>1η Σειρά Εργαστηρίου</center></h1>

# %% [markdown]
# **Σε κάθε εργαστήριο Python**, εισάγουμε πρώτα τις βιβλιοθήκες που θα χρησιμοποιήσουμε: εδώ, θα χρειαστούμε τις ``numpy``, ``matplotlib``, ``IPython``.
# Επιλέξτε το παρακάτω κελί κώδικα και πατήστε Shift + Enter, ώστε να το εκτελέσετε. Το ίδιο θα κάνετε με οποιοδήποτε κελί κώδικα. Αν τροποποιήσετε κάποιο κελί κώδικα, θα πρέπει να το ξανατρέξετε για να δείτε τα αποτελέσματά του.
#
# Δε χρειάζεται να εισάγετε τις βιβλιοθήκες αυτές σε κάθε άσκηση/υποερώτημα. Μια φορά στην αρχή του κώδικα είναι αρκετό, αρκεί να τρέχετε κάθε φορά που ανοίγετε το .ipynb αρχείο αυτό το πρώτο κελί που βλέπετε παρακάτω.

# %%
import numpy as np                 # εισάγουμε τη βιβλιοθήκη numpy και θα τη "φωνάζουμε" np
import matplotlib.pyplot as plt    # εισάγουμε τη συνάρτηση pyplot της βιβλιοθήκης matplotlib και θα τη "φωνάζουμε" plt
from matplotlib import cm
from IPython.display import Audio

# %% [markdown]
# Στην Python, η χρήση μιγαδικών αριθμών είναι πολύ απλή. Σημειώστε ότι η φανταστική μονάδα $j=\sqrt{-1}$ είναι δεσμευμένη μεταβλητή. Μπορείτε να την κάνετε overwrite με κάποιον άλλο αριθμό αλλά αυτό δεν συνιστάται όταν δουλεύετε με μιγαδικούς αριθμούς. Θα δείτε παρακάτω ότι για να τη χρησιμοποιήσετε πρέπει να τη συντάσσετε ως ``a*j`` και όχι ως απλό ``j``, με ``a`` πραγματικό αριθμό.
#
# Όταν θέλετε πληροφορίες για κάποια έτοιμη συνάρτηση της Python, γράψτε `help(function_name)` όπως για παράδειγμα (εκτελέστε το παρακάτω κελί επιλέγοντάς το και πατώντας Shift + Enter)

# %%
help(np.abs)

# %% [markdown]
# ---
# ---

# %% [markdown]
# ### Άσκηση 1

# %% [markdown]
# (α') Η συνάρτηση `roots` της `NumPy` υπολογίζει ρίζες πολυωνύμων. Για παράδειγμα, για το πολυώνυμο
# <br>
# $$ x^2+3x+2$$
#
# η σύνταξη είναι η παρακάτω: (εκτελέστε το παρακάτω κελί επιλέγοντάς το και πατώντας Shift + Enter)

# %%
coeffs = [1, 3, 2]              # συντελεστές πολυωνύμου x^2 + 3x + 2
r = np.roots(coeffs)            # κλήση της συνάρτησης roots, της βιβλιοθήκης numpy

print(f"Οι ρίζες του πολυωνύμου είναι οι r = {r}")

# %% [markdown]
# Βρείτε τις απαντήσεις της Άσκησης 6 από τις θεωρητικές σας ασκήσεις με χρήση της `Python`. Χρησιμοποιήστε το παρακάτω κελί.
#
# Θα παρατηρήσετε ότι σε κάποιες από τις απαντήσεις σας θα υπάρχουν διαφορές σε σχέση με τη θεωρητική λύση. Επιβεβαιώστε όμως ότι αυτό συμβαίνει σε αριθμούς ΠΑΡΑ ΠΟΛΥ μικρούς ($\approx 10^{-16}$, που στην ``Python`` εμφανίζονται στη μορφή $e^{-16}$ - το $e$ αυτό δεν έχει σχέση με το $e = 2.7182...$ που χρησιμοποιούμε στο μάθημα, είναι απλά ένας συμβολισμός του "10 εις την"!), οπότε το αριθμητικό σφάλμα της ``roots`` είναι αμελητέο.

# %%
# Άσκηση 6α
coeffs1 = # insert code here
r1 = # insert code here
print(f"a. Οι ρίζες του πολυωνύμου είναι οι z1 = {r1}\n")

# Επιβεβαίωση
z1_true = [2*np.exp(1j*(2*np.pi*k/3 - np.pi/6)) for k in range(0,3)]
print(f"a. Οι ρίζες του πολυωνύμου από τη θεωρία είναι οι z1_true = {np.asarray(z1_true)}\n")

# Άσκηση 6b
coeffs2 = # insert code here
r2 = # insert code here
print(f"b. Οι ρίζες του πολυωνύμου είναι οι z2 = {r2}\n")

# Επιβεβαίωση
z2_true = [(64)**(1/4)*np.exp(1j*((np.pi*k)/2 + np.pi/4)) for k in range(0,4)]
print(f"b. Οι ρίζες του πολυωνύμου από τη θεωρία είναι οι z2_true = {np.asarray(z2_true)}\n")

# Άσκηση 6γ
coeffs3 = # insert code here
r3 = # insert code here
print(f"c. Οι ρίζες του πολυωνύμου είναι οι z3 = {r3}\n")

# Επιβεβαίωση
z3_true = [np.exp(1j*(2*np.pi*k/5 + np.pi/10)) for k in range(0,5)]
print(f"c. Οι ρίζες του πολυωνύμου από τη θεωρία είναι οι z3_true = {np.asarray(z3_true)}\n")

# %% [markdown]
# (β') Η απεικόνιση συναρτήσεων στην `Python` είναι εύκολη. Αν για παράδειγμα θέλετε να απεικονίσετε ένα ημίτονο της μορφής
# $$ x(t)=2\cos(5\pi t)$$
#
# στο διάστημα $[-1,1)$, ο παρακάτω κώδικας θα το κάνει για σας. Μελετήστε τον γραμμή-γραμμή και τρέξτε τον. (εκτελέστε το παρακάτω κελί επιλέγοντάς το και πατώντας Shift + Enter)

# %%
t = np.arange(start=-1, stop=1, step=0.01)   # Ορίζουμε τον άξονα του χρόνου: ξεκινάμε από το -1, σταματάμε στο 1, με βήμα 0.01. Προσέξτε, το σημείο 1 δεν περιλαμβάνεται, δηλ.
                                             # το διάστημα είναι [-1,1).
x = 2 * np.cos(5*np.pi*t)                    # Ορίζουμε τη συνάρτησή μας

plt.figure(figsize=(12,3))            # Ορίζουμε ότι θέλουμε να φτιάξουμε ένα γράφημα
plt.plot(t, x, '-', color='tab:blue') # Φτιάχνουμε το γράφημα
plt.xlim([min(t), max(t)])            # Ομορφαίνουμε
plt.grid(linestyle=':')               # --||--
plt.title('A simple sinusoid')        # --||--
plt.xlabel('Time (s)')                # --||--

# %% [markdown]
# Μια μικρή επεξήγηση: δε θα μπορούσαμε να αποθηκεύσουμε όλες τις τιμές μιας συνάρτησης συνεχούς χρόνου, καθώς αυτές είναι άπειρες και η χωρητικότητα του υπολογιστή μας πεπερασμένη. Αυτό που κάνουμε στο διάνυσμα $t$ είναι να πάρουμε <em>δείγματα</em> από το συνεχή άξονα $t$. Ξεκινάμε από τον αριθμό $t=-1$ και διανύουμε τον άξονα με βήμα $dt=0.01$, καταλήγοντας στη χρονική στιγμή $t=1$ (χωρίς να συμπεριλαμβάνουμε το σημείο, όταν χρησιμοποιούμε τη συνάρτηση `arange` της `NumPy`).
#
# Στη συνέχεια ζητάμε από την Python να υπολογίσει για μας τις τιμές της ημιτονοειδούς συνάρτησης στις χρονικές στιγμές που υπάρχουν στο διάνυσμα $t$. Η συνάρτηση `plt.plot` της `matplotlib` αναλαμβάνει την απεικόνιση σε γράφημα, ενώ οι υπόλοιπες εντολές είναι διακοσμητικού χαρακτήρα (αλλά πολύ επεξηγηματικές για αυτόν/ήν που διαβάζει το γράφημα).

# %% [markdown]
# Τυπώστε στην `Python` τις συναρτήσεις:
#
# (i') $$x(t) = t^2 e^{-2t}, \ t \in [0,5)$$
#
# (ii') $$x(t) = \cos(2\pi 20t) + \sin(2\pi 50t), \ t \in [-3,3)$$
#
# (iii') $$ x(t) = t^2 + 2t + 1, \ t \in [-5, 5)$$
#
# (iv') $$ x(t) = \frac{t^3}{t^4-1}, \ t \in (0,2)$$

# %% [markdown]
# Γράψτε σε σχόλιο παρακάτω τι παρατηρείτε ότι συμβαίνει στο γράφημα της τελευταίας περίπτωσης. Χρησιμοποιήστε το παρακάτω κελί για τον κώδικα...

# %%
# Insert code here

# (i)
t = # insert code here               # Ορίζουμε τον άξονα του χρόνου: ξεκινάμε από το 0, σταματάμε στο 5, με βήμα 0.01. Προσέξτε, το σημείο 5 δεν περιλαμβάνεται.
x = # insert code here               # Ορίζουμε τη συνάρτησή μας

plt.figure(figsize=(12,3))            # Ορίζουμε ότι θέλουμε να φτιάξουμε ένα γράφημα
plt.plot(t, x, '-', color='tab:blue') # Φτιάχνουμε το γράφημα
plt.xlim([min(t), max(t)])            # Ομορφαίνουμε
plt.grid(linestyle=':')               # --||--
plt.title('(a)')                      # --||--
plt.xlabel('Time (s)')                # --||--

# (ii)
t = # insert code here                # Ορίζουμε τον άξονα του χρόνου: ξεκινάμε από το -3, σταματάμε στο 3, με βήμα 0.01. Προσέξτε, το σημείο 3 δεν περιλαμβάνεται.
x = # insert code here                # Ορίζουμε τη συνάρτησή μας

plt.figure(figsize=(12,3))            # Ορίζουμε ότι θέλουμε να φτιάξουμε ένα γράφημα
plt.plot(t, x, '-', color='tab:blue') # Φτιάχνουμε το γράφημα
plt.xlim([min(t), max(t)])            # Ομορφαίνουμε
plt.grid(linestyle=':')               # --||--
plt.title('(b)')                      # --||--
plt.xlabel('Time (s)')                # --||--

# (iii)
t = # insert code here                 # Ορίζουμε τον άξονα του χρόνου: ξεκινάμε από το -5, σταματάμε στο 5, με βήμα 0.01. Προσέξτε, το σημείο 5 δεν περιλαμβάνεται.
x = # insert code here                 # Ορίζουμε τη συνάρτησή μας

plt.figure(figsize=(12,3))            # Ορίζουμε ότι θέλουμε να φτιάξουμε ένα γράφημα
plt.plot(t, x, '-', color='tab:blue') # Φτιάχνουμε το γράφημα
plt.xlim([min(t), max(t)])            # Ομορφαίνουμε
plt.grid(linestyle=':')               # --||--
plt.title('(c)')                      # --||--
plt.xlabel('Time (s)')                # --||--

# (iv)
t = # insert code here                # Ορίζουμε τον άξονα του χρόνου: ξεκινάμε από το 0.01, σταματάμε στο 2, με βήμα 0.01. Προσέξτε, το σημείο 2 δεν περιλαμβάνεται.
x = # insert code here                # Ορίζουμε τη συνάρτησή μας

plt.figure(figsize=(12,3))            # Ορίζουμε ότι θέλουμε να φτιάξουμε ένα γράφημα
plt.plot(t, x, '-', color='tab:blue') # Φτιάχνουμε το γράφημα
plt.xlim([min(t), max(t)])            # Ομορφαίνουμε
plt.grid(linestyle=':')               # --||--
plt.title('(d)')                      # --||--
plt.xlabel('Time (s)')                # --||--

# %% [markdown]
# ...και το παρακάτω κελί για το σχόλιό σας για τη (δ):

# %% [markdown]
# ---
# ---

# %% [markdown]
# ### Άσκηση 2

# %% [markdown]
# Ο παρακάτω κώδικας εκτυπώνει τμήμα του πραγματικού μέρους της γραφικής παράστασης του *μιγαδικού* σήματος
#
# $$x(t)=\mathrm{Re}\{(1+j)e^{j2\pi 120t} \}$$
#
# παίρνοντας τιμές του σήματος $x(t)$ ανά $1/6000$ δευτερόλεπτα στο διάστημα $[-0.05, 0.15]$ s. Δηλ. $6000$ τιμές της συνάρτησης $x(t)$ σε ένα δευτερόλεπτο!
#
# Διαβάστε το πιο κάτω κελί, επιλέξτε το, και πατήστε Shift + Enter για να το τρέξετε.

# %%
f0 = 120                                                   # μια τιμή για τη συχνότητα του εκθετικού
Z = (1+1j)                                                 # ο phasor του μιγαδικού εκθετικού
dt = 1/6000                                                # ο ρυθμός που παίρνουμε δείγματα από τη συνεχή συνάρτηση x(t)
t = np.arange(start=-0.05, stop=0.15, step=dt)             # ο άξονας του χρόνου: από -0.05 ως 0.15, με "βήμα" dt
xx = (Z * np.exp(1j*2*np.pi*f0*t)).real                    # η συνάρτησή μας!

plt.figure(figsize=(12,3))                                 # Απεικόνιση: ανοίγουμε ένα figure
plt.plot(t, xx)                                            # Καλούμε την plt.plot για την απεικόνιση
plt.grid(linestyle=':')                                    # Ομορφαίνουμε 
plt.xlabel('Time (s)')                                     # Ομορφαίνουμε 
plt.title('Real part of signal x(t)')                      # Ομορφαίνουμε  
plt.xlim([min(t), max(t)])                                 # Ομορφαίνουμε 
plt.show()                                                 # Ομορφαίνουμε

# %% [markdown]
# Διαβάστε λοιπόν προσεκτικά τον παραπάνω κώδικα και παραδώστε κώδικα που τυπώνει στο ίδιο διάστημα και με το ίδιο $dt$:
#
# (α') το σήμα
# $$x(t) = e^{-2t}\cos\left(2\pi 200t + \frac{\pi}{4} \right)$$
#
# (β') το πραγματικό και το φανταστικό μέρος του σήματος
# $$z(t) = 2e^{-4t}e^{j(2\pi 180t+ \pi/3)}$$
#
# Παραδώστε τον κώδικα και τις γραφικές παραστάσεις που προκύπτουν.

# %%
dt = 1/6000                                            # Σας δίνουμε το "βημα" ...
t = np.arange(start=-0.05, stop=0.15, step=dt)         # ...και τον άξονα του χρόνου t

# (a') 
xx = # insert code here

# insert code here

# %%
# (b')

zz = # insert code here

# Τυπώνουμε το πραγματικό μέρος...

# insert code here

# ...και το φανταστικό μέρος

# insert code here

# %% [markdown]
# ---
# ---

# %% [markdown]
# ### Άσκηση 3

# %% [markdown]
# Η απεικόνιση μιγαδικών συναρτήσεων είναι ελαφρά διαφορετική. Δεδομένου ότι οι συναρτήσεις αυτές είναι της μορφής $f : A \subset \mathbb{C} \rightarrow \mathbb{C}$, δεν μπορούμε να τις απεικονίσουμε ρητά - η συνάρτηση είναι τεσσάρων διαστάσεων, εν γένει. Θα απεικονίσουμε είτε το πραγματικό και το φανταστικό μέρος, είτε το μέτρο και τη φάση τους. Για παράδειγμα, έστω η μιγαδική συνάρτηση

# %% [markdown]
# $$ f(z)=3\sin(z)$$

# %% [markdown]
# την οποία θέλουμε να απεικονίσουμε στο μιγαδικό επίπεδο, στο "πλέγμα" $[-5,5) \times [-5, 5)$.
#
# Οι παρακάτω εντολές πραγματοποιούν την απεικόνιση του πραγματικού και του φανταστικού μέρους της συνάρτησης:

# %%
range1 = np.arange(start=-5, stop=5, step=0.1)     # ο άξονας των πραγματικών (ο ίδιος θα είναι και ο φανταστικός, αφού το πλέγμα είναι συμμετρικό)
x,y = np.meshgrid(range1, range1, indexing='ij')   # δημιουργία πλέγματος
Z = x + 1j*y                                       # υπολογισμός του μιγαδικού Ζ στο πλέγμα
f = 3*np.sin(Z)                                    # υπολογισμός της συνάρτησης f(Z)

# %%
plt.figure(figsize=(16,12))                           # Ορίζουμε αν θέλουμε το μέγεθος του γραφήματος

ax1 = plt.subplot(2, 2, 1, projection='3d')           # Δηλώνουμε ότι θα έχει δυο μέρη, σε 3Δ προβολή, και ότι τώρα θα ασχοληθούμε με το αριστερό
ax1.plot_surface(X=x, Y=y, Z=f.real, cmap=cm.viridis) # Τυπώνουμε το πραγματικό μέρος (το cmap αφορά το χρωματισμό)
plt.xlabel('$\mathfrak{Re}\{z\}$')                    # Ομορφαίνουμε
plt.ylabel('$\mathfrak{Im}\{z\}$')                    # --||--
plt.title('$\mathfrak{Re}\{3\sin(z)\}$')              # --||--

ax2 = plt.subplot(2, 2, 2, projection='3d')           # Δηλώνουμε ότι θα έχει δυο μέρη, σε 3Δ προβολή, και ότι τώρα θα ασχοληθούμε με το δεξί
ax2.plot_surface(X=x, Y=y, Z=f.imag, cmap=cm.viridis) # Τυπώνουμε το φανταστικό μέρος (το cmap αφορά το χρωματισμό)
plt.xlabel('$\mathfrak{Re}\{z\}$')                    # Ομορφαίνουμε
plt.ylabel('$\mathfrak{Im}\{z\}$')                    # --||--
plt.title('$\mathfrak{Im}\{3\sin(z)\}$')              # --||--

# %% [markdown]
# (α') Χρησιμοποιείστε τις συναρτήσεις `abs`, `angle`, της `NumPy` για να απεικονίσετε το μέτρο $|f(z)|$ και τη φάση $\phi(z)$ της παραπάνω συνάρτησης στο ίδιο πεδίο ορισμού.
#
# (β') Επιπλέον, σχεδιάστε το πραγματικό και το φανταστικό μέρος της συνάρτησης $$f(z)=e^z$$ στο "πλέγμα" $[-5,5)\times[-10,10)$. Χρησιμοποιήστε τη συνάρτηση `exp` της `NumPy`.

# %%
# (α')
range1 = np.arange(start=-5, stop=5, step=0.1)   # Σας δίνουμε τον πρώτο άξονα, [-5,5)
range2 = # insert code here                      # Φτιάξτε το δεύτερο άξονα, [-5,5)
x,y = np.meshgrid(range1, range2, indexing='ij') # δημιουργία πλέγματος
Z = x + 1j*y                                     # υπολογισμός μιγαδικού Ζ στο πλέγμα
f = # insert code here                           # υπολογισμός συνάρτησης

plt.figure(figsize=(16,12))                       # Δημιουργία γραφήματος (χρησιμοποιήστε τον έτοιμο κώδικα παραπάνω, με κατάλληλη τροποποίηση)

# Insert code here








# End of code

# %%
# (β')
range1 = np.arange(start=-5, stop=5, step=0.1)   # Σας δίνουμε τον πρώτο άξονα, [-5,5)
range2 = # insert code here                      # Φτιάξτε το δεύτερο άξονα, [-10,10)
x,y = np.meshgrid(range1, range2, indexing='ij') # δημιουργία πλέγματος
Z = x + 1j*y                                     # υπολογισμός μιγαδικού Ζ στο πλέγμα
f = # insert code here                           # υπολογισμός συνάρτησης

plt.figure(figsize=(16,12))                       # Δημιουργία γραφήματος (χρησιμοποιήστε τον έτοιμο κώδικα παραπάνω, με κατάλληλη τροποποίηση)

# Insert code here








# End of code

# %% [markdown]
# ---
# ---

# %% [markdown]
# ### Άσκηση 4

# %% [markdown]
# Στο μάθημα μιλήσαμε αρκετά για τα ημιτονοειδή σήματα, το πλάτος, τη συχνότητα, και την αρχική φάση τους. Η γενική έκφραση που χρησιμοποιήσαμε ήταν η
#
# $$ x(t) = A\cos(2\pi f_0 t + \phi)$$
#
# με $A, f_0, \phi$ το πλάτος, η συχνότητα, και η φάση αντίστοιχα.
#
# Κάθε ημιτονοειδές τέτοιας μορφής έχει σταθερή συχνότητα ίση με $f_0$ Hz. Ας ακούσουμε ένα τέτοιο ημιτονοειδές συχνότητας $500$ Hz.

# %%
fs = 16000                         # συχνότητα δειγματοληψίας - θα μάθετε αργότερα γι'αυτήν
f0 = 500                           # συχνότητα

n = np.arange(0, 2*fs)             # άξονας διακριτού χρόνου 2 δευτερολέπτων
output = np.cos(2*np.pi*f0*n/fs)   # ημιτονοειδές - προσέξτε, ο χρόνος t γράφεται ως n/fs !

Audio(output, rate=fs)             # ακούστε! :)

# %% [markdown]
# Μιλώντας λίγο πιο τεχνικά, η **στιγμιαία** συχνότητα αποτελεί την πρώτη παράγωγο του ορίσματος ενός ημιτονοειδούς σήματος, με βάση τη σχέση
#
# $$ f(t) = \frac{1}{2\pi}\frac{d}{dt}\Phi(t) $$
#
# με $\Phi(t)$ τη **συνολική φάση** του ημιτονοειδούς, δηλ. στην περίπτωση που μελετάμε παραπάνω
#
# $$\Phi(t) = 2\pi f_0 t + \phi \Longrightarrow f(t) = \frac{1}{2\pi}\frac{d}{dt}(2\pi f_0 t + \phi) = f_0$$
#
# Βλέπετε ότι στην περίπτωση μας, η στιγμιαία συχνότητα είναι σταθερή και ταυτίζεται με την $f_0$. Τι συμβαίνει όμως αν ένα ημιτονοειδές **δεν** έχει σταθερή συχνότητα?
#
# Ας δούμε εδώ ένα τέτοιο παράδειγμα.
#
# (α') Τα chirp σήματα είναι σήματα στα οποία η συχνότητα αυξάνεται ή μειώνεται µε την πάροδο του χρόνου. Τέτοια σήματα έχουν εφαρμογές σε συστήματα radar και sonar, και σε τηλεπικοινωνιακά συστήματα. Θέλουμε να δημιουργήσουμε ένα chirp σήμα το οποίο θα έχει **γραμμικά** αυξανόμενη στιγμιαία συχνότητα $f(t)$, ξεκινώντας από τα $f_{\text{begin}} = 100$ Hz και φτάνοντας στα $f_{\text{end}} = 2000$ Hz. Θέλουμε η αύξηση αυτή να γίνεται μέσα σε χρόνο $t = 4$ δευτερόλεπτα, ξεκινώντας από $t = 0$.
#
# Με άλλα λόγια, θέλουμε μια "καμπύλη" συχνότητας που σε ένα νοητό χώρο (χρόνου, συχνότητας) να ξεκινά από το σημείο $(0, 100)$ και να καταλήξει στο σημείο $(4, 2000)$. Η εξίσωση μιας τέτοιας ευθείας, δηλ. που περνά από δυο γνωστά σημεία $(x_0, y_0)$, $(x_1, y_1)$ - μας είναι γνωστή από τα μαθηματικά:
#
# $$y-y_0 = \frac{y_1-y_0}{x_1-x_0}(x-x_0)$$
#
# και στην περίπτωσή μας θα είναι
#
# $$f(t) - 100 = \frac{2000-100}{4-0}(t-0) \Longleftrightarrow f(t) = 100 + \frac{1900}{4}t = 100 + 475t$$
#
# Ας τη σχεδιάσουμε:

# %%
fs = 16000                      # συχνότητα δειγματοληψίας - θα μάθετε αργότερα γι'αυτήν
t = np.arange(0, 4, 1/fs)       # άξονας χρόνου
f = 100 + 475*t                 # στιγμιαία συχνότητα

plt.figure()                    # σχήμα
plt.plot(t, f)                  # γράφημα
plt.grid(linestyle=':')         # ομορφαίνουμε
plt.xlabel('Χρόνος $(s)$')      # --- || ----
plt.ylabel('Συχνότητα (Hz)')    # --- || ----
plt.title('Γραμμική μεταβολή συχνότητας για ένα chirp σήμα') # --- || ----
plt.xlim([min(t), max(t)])      # --- || ----
plt.show()                      # --- || ----

# %% [markdown]
# Για να την ακούσουμε, πρέπει να τη "φορτώσουμε" στη **συνολική φάση** $\Phi(t)$ σε ένα ημιτονοειδές, με τέτοιο τρόπο ώστε αν παραγωγίσουμε αυτή τη **συνολική** του φάση να πάρουμε ακριβώς τη στιγμιαία συχνότητα που βρήκαμε παραπάνω.
#
# Με άλλα λόγια, χρειαζόμαστε η συνολική φάση $\Phi(t)$ να είναι
#
# $$\Phi(t) = 2\pi \int_0^t f(u)du$$
#
# έτσι ώστε πράγματι
#
# $$f(t) = \frac{1}{2\pi}\frac{d}{dt}\Phi(t)$$
#
# Στο παράδειγμά μας, η συνολική φάση $\Phi(t)$ θα είναι
#
# \begin{align*}
#     \Phi(t) &= 2\pi \int_0^t f(u) du \\
#     &= 2\pi \int_0^t (100 + 475u) du \\
#     &= 2\pi \left(100u + 475 \frac{u^2}{2}\right)\Big|_{u=0}^{u=t} \\
#     &= 2\pi \left(100t + 475\frac{t^2}{2}\right) \\
#     &= 2\pi 100t + 475\pi t^2
# \end{align*}
#
# για $0 < t < 4$ δευτερόλεπτα. Αυτή θα είναι η συχνολική φάση του ημιτονοειδούς μας! 😃 Προγραμματίστε και ακούστε την στο παρακάτω κελί κώδικα.

# %%
fs = 16000                         # συχνότητα δειγματοληψίας - θα μάθετε αργότερα γι'αυτήν
n = np.arange(0, 4*fs)             # άξονας διακριτού χρόνου

Phi = # insert code here           # συνολική φάση - χρησιμοποιήστε όπου t το n/fs!

output = np.cos(Phi)               # ημιτονοειδές
Audio(output, rate=fs)             # ακούστε! :)

# %% [markdown]
# (β') Έστω ότι τώρα θέλουμε να δημιουργήσουμε ένα chirp σήμα που θα έχει **πολυωνυμικά** αυξανόμενη συχνότητα, και συγκεκριμένα µε παραβολική αύξηση, ξανά σε διάστημα $t = 4$ δευτερολέπτων!
#
# Για την κατασκευή της συνάρτησης στιγμιαίας συχνότητας $f(t)$ θα χρειαστείτε τρία σημεία: ας υποθέσουμε ότι αυτά είναι τα
#
# $$(t_i, f_i) = (0,200), (2,1000), (4,4000), \: \: i=1,2,3$$
#
# µε την πρώτη τιμή κάθε ζεύγους να δηλώνει το χρόνο σε δευτερόλεπτα, και τη δεύτερη τιμή να δηλώνει την τιμή της στιγμιαίας συχνότητας σε Hz. Άρα από τα παραπάνω σημεία συμπεραίνουμε ότι η στιγμιαία συχνότητα ξεκινά από τα $200$ Hz για $t = 0$, φτάνει τα $1000$ Hz όταν $t = 2$, και καταλήγει στα $4000$ Hz για $t = 4$. Υπενθυμίζεται ότι µια παραβολή είναι της μορφής
#
# $$f(t) = a + bt + ct^2$$

# %% [markdown]
# (i) Βρείτε τους αγνώστους $a, b, c$ λύνοντας το σύστημα που προκύπτει από τη γνώση των σημείων $(t_i, f_i)$ σε ένα χαρτί, και γράψτε την εξίσωση της στιγμιαίας συχνότητας $f(t)$. Σχεδιάστε την όπως πριν.
#
# (ii) Υπολογίστε τη φάση $\Phi(t)$ ολοκληρώνοντάς την $f(t)$ όπως στο προηγούμενο παράδειγμα.
#
# (iii) Γράψτε το ημιτονοειδές σήμα στο χρόνο $x(t)$ που τελικά προκύπτει. Αν όλα πάνε καλά, θα πρέπει να βρείτε
#
# $$x(t) = \cos\left(2\pi\left(\frac{275}{3}t^3 - 75t^2 + 200t\right)\right)$$
#
# (iv) Ακούστε αυτό το σήμα.
#
# Ακολουθήστε τον παρακάτω σκελετό για τα ερωτήματα αυτά.

# %%
# (i)
a = # insert code here
b = # insert code here
c = # insert code here

# Σχεδίαση
t = np.arange(0, 4, 1/fs)       # άξονας χρόνου
f = # insert code here          # στιγμιαία συχνότητα

plt.figure()                    # σχήμα
plt.plot(t, f)                  # γράφημα
plt.grid(linestyle=':')         # ομορφαίνουμε
plt.xlabel('Χρόνος $(s)$')      # --- || ----
plt.ylabel('Συχνότητα (Hz)')    # --- || ----
plt.title('Γραμμική μεταβολή συχνότητας για ένα chirp σήμα') # --- || ----
plt.xlim([min(t), max(t)])      # --- || ----
plt.show()                      # --- || ----

# %%
fs = 16000                      # συχνότητα δειγματοληψίας
n = np.arange(0, 4*fs)          # άξονας χρόνου (4 δευτερόλεπτα)

# (ii)
Phi = # insert code here          # συνολική φάση - χρησιμοποιήστε όπου t το n/fs!

# (iii)
x = # insert code here            # ημιτονοειδές

# (iv)
Audio(x, rate=fs)                  # ακούστε! :)

# %% [markdown]
# ***
# ***
# ## Παραδοτέα:
# ***
# ### Μετονομάστε το **συμπληρωμένο και με εκτελεσμένο κάθε κελί κώδικα** notebook σε
#
# ## *HY215-Lab1-2025-CSDXXXX.ipynb*,
#
# ### με *XXXX* ο αριθμός μητρώου σας.
#
# ### Αν είστε με προσωρινό κωδικό λόγω μεταγραφής, τότε ονομάστε το αρχείο σας
#
# ## *HY215-Lab1-2025-mtgXXXX.ipynb*,
#
# ### με *XXXX* ο προσωρινός αριθμός μητρώου σας.
#
# ### Αν είστε από άλλο τμήμα πέραν του CSD, τότε ονομάστε το αρχείο σας
#
# ## *HY215-Lab1-2025-DPTXXXX.ipynb*,
#
# ### με *DPT* να είναι ένα εκ των {MATH, PHYS} και *XXXX* ο αριθμός μητρώου σας.
#
# ### Στείλτε το μετονομασμένο notebook ως επισυναπτόμενο αρχείο με e-mail στο csd5176@csd.uoc.gr .
#
# ### Στο e-mail θα αναγράφετε:
#
# ### - Τίτλος: [ΗΥ215] 1ο εργαστήριο Python
#
# ### και στο σώμα του e-mail τα παρακάτω:
#
# ### - Ονοματεπώνυμο
# ### - ΑΜ

# %% [markdown]
# ### ΠΡΟΣΕΞΤΕ: Το παραδοτέο αρχείο σας πρέπει να έχει extension .ipynb, και ΟΧΙ κάτι άλλο!!
